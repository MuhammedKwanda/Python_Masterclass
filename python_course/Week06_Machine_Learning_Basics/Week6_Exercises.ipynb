# %% [markdown]
# # 📝 Week 6 Exercises
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass

# %% [markdown]
# ## Exercise 1 — Regression (30 pts)

# %%
# Predict monthly electricity bill from:
# rooms, appliances_owned, generator_hours_per_day
# Create realistic data, train, evaluate, interpret

# Your code here

# %% [markdown]
# ## Exercise 2 — Classification (30 pts)

# %%
# Titanic or similar: predict survival from age, gender, class
# Train Logistic Regression, confusion matrix, report
# Explain precision vs recall in this context

# Your code here

# %% [markdown]
# ## Exercise 3 — Evaluation Deep Dive (40 pts)

# %%
# Disease detection: 1000 patients, 100 have disease
# Train two models with different thresholds
# Show precision-recall tradeoff
# Recommend threshold and justify

# Your code here
