# %% [markdown]
# # 🏠 Week 6 Project Starter — House Price Prediction
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline

np.random.seed(42)
n=500
df=pd.DataFrame({
    "size_sqm": np.random.randint(50,500,n),
    "bedrooms": np.random.randint(1,6,n),
    "bathrooms": np.random.randint(1,4,n),
    "distance_km": np.random.uniform(1,30,n),
    "location": np.random.choice(["Island","Mainland","Suburbs"],n)
})
df["price_M"]=df["size_sqm"]*0.08+df["bedrooms"]*5-df["distance_km"]*2+df["location"].map({"Island":30,"Mainland":15,"Suburbs":5})+np.random.normal(0,5,n)
df["price_M"]=df["price_M"].clip(5,500)
print(df.head())

# %% [markdown]
# ## TODO

# %%
# 1. Explore and visualize
# 2. Encode location
# 3. Train/test split
# 4. Train LinearRegression
# 5. Evaluate RMSE and R2
# 6. Interpret coefficients
# 7. Predict 3 specific houses

# Your code here
