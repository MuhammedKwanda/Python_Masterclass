# %% [markdown]
# # 📦 Modules & Packages
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass

# %%
import math
print(math.pi)
print(math.sqrt(16))
print(math.factorial(5))

import random
print(random.randint(1, 100))
print(random.choice(["heads", "tails"]))

import datetime
now = datetime.datetime.now()
print(now.strftime("%Y-%m-%d %H:%M"))

# %%
from math import sqrt, pi
from random import shuffle, sample

names = ["Amina","Bello","Chioma","Dauda"]
shuffle(names)
print(names)
print(sample(names, 2))

# %%
import json
from collections import Counter

data = {"name": "Kwanda", "gpa": 9.25, "courses": ["Security","ML"]}
json_str = json.dumps(data, indent=2)
print(json_str)
loaded = json.loads(json_str)
print(loaded["name"])

words = ["python","is","great","python","is","python"]
counter = Counter(words)
print(counter.most_common(2))

# %% [markdown]
# ## 📝 Exercise

# %%
# 1. Use 'calendar' module to print current month's calendar
# 2. Use 'os' to: print cwd, create folder, list files
# 3. Write student data to JSON, read it back

# Your code here
