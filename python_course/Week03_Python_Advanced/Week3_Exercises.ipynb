# %% [markdown]
# # 📝 Week 3 Exercises
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass

# %% [markdown]
# ## Exercise 1 — Student Management System (30 pts)

# %%
# StudentManagement class:
# - store students (name, ID, scores list)
# - add/remove students
# - calculate average and grade per student
# - print class report
# - save/load from JSON

# Your code here

# %% [markdown]
# ## Exercise 2 — File Word Counter (25 pts)

# %%
# Create a text file with 3+ paragraphs
# Count: total words, unique words, sentences
# Find 5 most common words
# Save summary to new file

# Your code here

# %% [markdown]
# ## Exercise 3 — Comprehension Challenges (25 pts)

# %%
# Using ONLY comprehensions (no regular loops):
# 1. From 1-100: numbers divisible by 3 OR 5 but not both
# 2. Flatten: [[1,2,3],[4,5,6],[7,8,9]]
# 3. Dict {word: length} for words in a sentence
# 4. Multiplication table as dict: {(i,j): i*j for 1..5}

# Your code here

# %% [markdown]
# ## Exercise 4 — Robust Calculator (20 pts)

# %%
# Calculator class:
# - add, subtract, multiply, divide
# - history of calculations
# - error handling
# - save/load history to file

# Your code here
