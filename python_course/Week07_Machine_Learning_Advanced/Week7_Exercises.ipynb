# %% [markdown]
# # 📝 Week 7 Exercises
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass

# %% [markdown]
# ## Exercise 1 — RF vs DT (25 pts)

# %%
from sklearn.datasets import load_wine
data=load_wine()
# 1. Train DT and RF
# 2. Compare accuracy/precision/recall per class
# 3. Plot feature importances
# 4. Vary DT max_depth

# Your code here

# %% [markdown]
# ## Exercise 2 — Full Pipeline (35 pts)

# %%
# Loan Approval:
# numeric: income, age, loan_amount, credit_score
# categorical: employment_type, education, marital_status
# target: approved (0/1)
# Build Pipeline + GridSearchCV

# Your code here

# %% [markdown]
# ## Exercise 3 — IDS Challenge (40 pts)

# %%
import numpy as np, pandas as pd
np.random.seed(42)
n=2000
normal=pd.DataFrame({"bytes_s":np.random.normal(1000,200,int(n*0.9)),"bytes_r":np.random.normal(2000,400,int(n*0.9)),"duration":np.random.normal(50,10,int(n*0.9)),"pkt_rate":np.random.normal(10,2,int(n*0.9)),"label":0})
attack=pd.DataFrame({"bytes_s":np.random.normal(5000,1000,int(n*0.1)),"bytes_r":np.random.normal(100,50,int(n*0.1)),"duration":np.random.normal(5,2,int(n*0.1)),"pkt_rate":np.random.normal(100,20,int(n*0.1)),"label":1})
df=pd.concat([normal,attack],ignore_index=True)
# 1. Class distribution
# 2. Random Forest with class_weight="balanced"
# 3. Evaluate focusing on ATTACK recall
# 4. GridSearchCV to maximize recall
# 5. Explain: why recall > precision for IDS?

# Your code here
