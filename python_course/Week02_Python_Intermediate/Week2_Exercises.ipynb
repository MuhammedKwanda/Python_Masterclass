# %% [markdown]
# # 📝 Week 2 Exercises
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass

# %% [markdown]
# ## Exercise 1 — Grade Calculator (20 pts)

# %%
# Ask for student name and 5 scores, calculate average, assign grade, print slip
# Your code here

# %% [markdown]
# ## Exercise 2 — Multiplication Table (20 pts)

# %%
# Ask for a number, print its table (1-12) formatted nicely
# Your code here

# %% [markdown]
# ## Exercise 3 — Prime Numbers (20 pts)

# %%
# Write is_prime(n), print all primes between 1 and 100
# Your code here

# %% [markdown]
# ## Exercise 4 — Student Records (20 pts)

# %%
# List of student dicts: name, scores(list of 4)
# Function: calculate average, assign grade, print class report
# Your code here

# %% [markdown]
# ## Exercise 5 — FizzBuzz (20 pts)

# %%
# 1-100: Fizz (mult 3), Buzz (mult 5), FizzBuzz (both), else number
# Your code here
