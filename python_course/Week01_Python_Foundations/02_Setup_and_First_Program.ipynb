# %% [markdown]
# # ⚙️ Setup & Your First Program
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass

# %% [markdown]
# ## Your First Program

# %%
print("Hello, World!")
print("My name is Muhammed")
print("I am learning Python!")

# %% [markdown]
# ## The print() Function

# %%
print("Hello")
print("Hello", "World")
print("Hello" + " " + "World")
print()
print("Line 1\nLine 2\nLine 3")

# %% [markdown]
# ## Comments
# Comments are lines Python ignores. Use them to explain your code.

# %%
# This is a single-line comment
print("Comments make code readable!")  # inline comment

# %% [markdown]
# ## Python Indentation
# Python uses **spaces** instead of `{}` to define blocks.

# %%
if True:
    print("Correctly indented")
    print("This too")

# %% [markdown]
# ## 📝 Exercise
# Write a program that prints:
# 1. Your full name
# 2. Your university
# 3. Your course
# 4. Why you want to learn Python

# %%
# Your code here
