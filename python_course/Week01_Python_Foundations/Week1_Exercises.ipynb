# %% [markdown]
# # 📝 Week 1 Exercises
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass
#
# > Complete all exercises and submit before next class.

# %% [markdown]
# ## Exercise 1 — Variables & Types (20 pts)

# %%
# Create variables for your name, age, GPA, student status, country
# Print each with its data type using type()

# Your code here

# %% [markdown]
# ## Exercise 2 — Arithmetic (20 pts)

# %%
# A shop sells: Rice=N5000/bag, Oil=N3500/bottle, Sugar=N1200/pack
# Customer buys: 3 bags rice, 2 bottles oil, 5 packs sugar
# 1. Total cost per item
# 2. Grand total
# 3. Change from N30,000
# 4. Final price with 10% discount

# Your code here

# %% [markdown]
# ## Exercise 3 — String Operations (20 pts)

# %%
sentence = "  python is the most popular programming language in data science  "
# 1. Remove whitespace
# 2. Convert to title case
# 3. Count letter "a"
# 4. Replace "data science" with "cybersecurity"
# 5. Split into words
# 6. Print the 3rd word

# Your code here

# %% [markdown]
# ## Exercise 4 — BMI Calculator (20 pts)

# %%
# Ask for name, weight (kg), height (m)
# BMI = weight / height^2
# Print result and category:
# Below 18.5: Underweight
# 18.5-24.9: Normal
# 25-29.9: Overweight
# 30+: Obese

# Your code here

# %% [markdown]
# ## Exercise 5 — Payslip Generator (20 pts)

# %%
# Ask for: employee name, basic salary, overtime hours, overtime rate
# Calculate: overtime pay, gross, tax (15%), net salary
# Print formatted payslip

# Your code here
