# %% [markdown]
# # 🏆 Capstone Project — End-to-End ML Pipeline
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass
#
# **Student Name:** _(your name)_
# **Dataset:** _(name and source)_
# **Problem Statement:** _(your question)_
#
# ---
#
# See `Capstone_Brief.md` for full requirements.

# %% [markdown]
# ## 1. Problem Statement
#
# *What business or real-world question are you answering? Why does it matter?*

# %% [markdown]
# ## 2. Dataset Overview

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
# %matplotlib inline

# TODO: Load your dataset
# df = pd.read_csv("your_dataset.csv")
# Show head, shape, info, describe

# %% [markdown]
# ## 3. Data Cleaning

# %%
# TODO: Handle missing values, duplicates, wrong types, outliers
# Show before/after comparison

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %%
# TODO: At least 4 meaningful visualizations
# Add markdown cells explaining each chart

# %% [markdown]
# ## 5. Feature Engineering

# %%
# TODO: Encode categoricals, scale numerics, select features

# %% [markdown]
# ## 6. Model Building & Evaluation

# %%
# TODO: At least 2 models, cross-validation, hyperparameter tuning

# %% [markdown]
# ## 7. Results & Conclusions

# %%
# TODO: Final model performance summary

# %% [markdown]
# ## ✍️ Written Conclusions
#
# ### What I Found
# 1. ...
# 2. ...
# 3. ...
#
# ### Limitations
# ...
#
# ### What I Would Do Next
# ...
#
# ### What I Learned
# ...
