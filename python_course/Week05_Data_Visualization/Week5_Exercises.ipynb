# %% [markdown]
# # 📝 Week 5 Exercises
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass

# %% [markdown]
# ## Exercise 1 — Nigerian Economic Data (30 pts)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data={"Year":list(range(2015,2025)),"GDP_Growth":[2.7,-1.6,0.8,1.9,2.2,-1.8,3.6,3.3,2.9,3.1],"Inflation":[9.0,15.7,16.5,12.1,11.4,13.2,16.5,18.8,24.7,28.9]}
df=pd.DataFrame(data)
# Create 3 charts that tell the story of this data

# Your code here

# %% [markdown]
# ## Exercise 2 — Tips Dataset (40 pts)

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
# 1. Distribution of tip amounts
# 2. Male vs female tipping
# 3. Busiest day by total bills
# 4. Total bill vs tip relationship
# 5. Smoking effect on tips

# Your code here

# %% [markdown]
# ## Exercise 3 — Your Own Dataset (30 pts)

# %%
# Find any interesting dataset from Kaggle or data.gov.ng
# Load, explore, create a 5-chart visual story
# Write 2-3 sentences per chart explaining what it shows

# Your code here
