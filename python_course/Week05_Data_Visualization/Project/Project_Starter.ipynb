# %% [markdown]
# # 📊 Week 5 Project Starter — Sales Dashboard
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="whitegrid")
np.random.seed(42)
months=["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
categories=["Electronics","Clothing","Food","Books","Sports"]
data=[]
for m in months:
    for c in categories:
        data.append({"Month":m,"Category":c,"Sales":np.random.randint(50000,500000),"Units":np.random.randint(50,500)})
df=pd.DataFrame(data)
print(df.head(10))

# %% [markdown]
# ## Create Your Dashboard (at least 6 charts)

# %%
# Chart 1: Monthly sales trend

# %%
# Chart 2: Sales by category

# %%
# Chart 3: Heatmap — category by month

# %%
# Charts 4, 5, 6 — Your choice!

# %% [markdown]
# ## ✍️ Narrative
# - **Best month:** ...
# - **Top category:** ...
# - **Key insight:** ...
# - **Recommendation:** ...
