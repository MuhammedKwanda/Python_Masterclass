# %% [markdown]
# # 📝 Week 4 Exercises
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass

# %% [markdown]
# ## Exercise 1 — NumPy Statistics (20 pts)

# %%
import numpy as np
np.random.seed(10)
sales = np.random.randint(50000, 500000, size=(4,12))
branches = ["Lagos","Abuja","Kano","Enugu"]
# 1. Total annual sales per branch
# 2. Monthly average across all branches
# 3. Best performing month
# 4. Branch with highest total
# 5. Months where any branch exceeded 400,000

# Your code here

# %% [markdown]
# ## Exercise 2 — Pandas Exploration (30 pts)

# %%
# Load a real dataset (Titanic recommended)
# 1. Load, display info
# 2. Handle missing values
# 3. Survival rate by gender and class
# 4. Average age of survivors vs non-survivors
# 5. Create AgeGroup: Child(<12), Teen(12-17), Adult(18-60), Senior(60+)

# Your code here

# %% [markdown]
# ## Exercise 3 — Full Data Pipeline (50 pts)

# %%
# Create a messy DataFrame (20+ rows)
# 1. Inspect
# 2. Clean
# 3. Transform and group
# 4. Answer 3 business questions
# 5. Export clean version to CSV

# Your code here
