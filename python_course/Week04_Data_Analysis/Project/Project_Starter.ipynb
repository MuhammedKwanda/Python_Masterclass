# %% [markdown]
# # 📊 Week 4 Project Starter — Student Performance Analysis
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com)
#
# **Instructor:** Muhammed Musa Kwanda | Python Masterclass
#
# > See `Project_Brief.md` for full requirements and grading rubric.

# %%
import pandas as pd
import numpy as np
np.random.seed(42)
n = 1000
df = pd.DataFrame({
    "gender": np.random.choice(["male","female"],n),
    "race": np.random.choice(["A","B","C","D","E"],n),
    "parental_edu": np.random.choice(["high school","some college","bachelor's","master's"],n),
    "lunch": np.random.choice(["standard","free/reduced"],n),
    "test_prep": np.random.choice(["none","completed"],n),
    "math_score": np.random.randint(0,100,n),
    "reading_score": np.random.randint(0,100,n),
    "writing_score": np.random.randint(0,100,n)
})
print("Dataset loaded!")
df.head()

# %% [markdown]
# ## Part 1 — Load & Explore

# %%
# TODO: shape, first 10 rows, data types, missing values, statistics

# %% [markdown]
# ## Part 2 — Data Analysis

# %%
# TODO:
# 1. Average score per subject
# 2. Gender performance comparison
# 3. Impact of test preparation
# 4. Parental education vs scores

# %% [markdown]
# ## Part 3 — Insights & Conclusions

# %%
# TODO: Support your findings with code

# %% [markdown]
# ## ✍️ Written Conclusions
#
# 1. **Finding 1:** ...
# 2. **Finding 2:** ...
# 3. **Finding 3:** ...
#
# **Recommendation:** ...
#
# **Additional data needed:** ...
